# %%
import pandas as pd
import numpy as np
import os
import shutil
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as plt
import re
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler


import mysql.connector
from mysql.connector import Error

import torch
import torch.nn as nn
import torch.optim as optim

# %%
def extract_cycle_substring(text, patern):
    
    match = re.search(pattern, text)
    if match:
        return match.group(0)
    else:
        return None

# %%
directory = r'C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2'

pattern_cycle = r'CYCLE\s(?:X{2}|X)\b'


xover_data = []



for file in os.listdir(directory):
    if file.endswith('.csv') and 'EIS' not in file and 'BUFFER' not in file:
        src = directory+ "\\" + file
        df = pd.read_csv(src,skiprows=17,dtype={'Unnamed: 0': object})
#         df['Unnamed: 0'] = pd.to_datetime(df['Unnamed: 0'], errors='coerce')
        df = df.drop(df.index[:2])
        df['path'] = file
        
        cycle = re.search(pattern_cycle, file)
#         df['cycle'] = cycle
        
        xover_data.append(df)
        
        
        print(src)

xover_data = pd.concat(xover_data)
xover_data
# Out:
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 1 ~ Datafile_Analyser ~ 240619 173806.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 2 ~ AN 0BAR, CA 0BAR CV ~ 240620 081920.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 2 ~ AN 0BAR, CA 0BAR ~ 12 Hour Dry Conditioning ~ 240619 173806.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 2 ~ AN 0BAR, CA 0BAR ~ Break in conditions  ~ 240621 032412.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 2 ~ AN 0BAR, CA 0BAR ~ Current Polar Down ~ 240620 070059.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 2 ~ AN 0BAR, CA 0BAR ~ Current Polar Up ~ 240620 055623.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 2 ~ CYCLE 1 ~ AN 2BAR 80C, CA 28.5BAR CV ~ 240621 055923.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 2 ~ CYCLE 1 ~ AN 2BAR 80C, CA 28.5BAR ~ Current Polar Down ~ 240621 044056.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 2 ~ CYCLE 1 ~ AN 2BAR 80C, CA 28.5BAR ~ Current Polar Up ~ 240621 033619.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 2 ~ CYCLE 1 ~ AN 2BAR 80C, CA 28.5BAR ~ H2 XOver ~ 240621 060546.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 2 ~ Datafile_Analyser ~ 240621 080444.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 3 ~ 0.00 ~ Break in conditions  ~ 240621 080445.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 3 ~ AN 0BAR, CA 0BAR ~ H2 XOver ~ 240620 083545.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 3 ~ CYCLE 1 ~ AN 2BAR 80C, CA 28.5BAR ~ Break in conditions  ~ 240622 002426.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 3 ~ CYCLE 1 ~ AN 2BAR 80C, CA 28.5BAR ~ H2 XOver ~ 240621 081754.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 3 ~ CYCLE 2 ~ AN 4BAR 80C, CA 28.5BAR CV ~ 240622 025229.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 3 ~ CYCLE 2 ~ AN 4BAR 80C, CA 28.5BAR ~ Break in conditions  ~ 240622 033657.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 3 ~ CYCLE 2 ~ AN 4BAR 80C, CA 28.5BAR ~ Current Polar Down ~ 240622 013411.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 3 ~ CYCLE 2 ~ AN 4BAR 80C, CA 28.5BAR ~ Current Polar Up ~ 240622 002934.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 3 ~ CYCLE 2 ~ AN 4BAR 80C, CA 28.5BAR ~ H2 XOver ~ 240622 025853.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 3 ~ CYCLE 3 ~ AN 6BAR 80C, CA 28.5BAR CV ~ 240622 055033.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 3 ~ CYCLE 3 ~ AN 6BAR 80C, CA 28.5BAR ~ Current Polar Down ~ 240622 043931.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 3 ~ CYCLE 3 ~ AN 6BAR 80C, CA 28.5BAR ~ Current Polar Up ~ 240622 034204.csv
# C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\LSTM-keras\50um\1079714-2\1079714-2 ~ E60#B ~ 3 ~ CYCLE 3 ~ AN 6BAR 80C, CA 28.5BAR ~ H2 XOver ~ 240622 055656.csv
#                    Time Stamp  Elapsed Time     File Mark  voltage   current  \
# 2     2024-06-19 17:39:30.005        83.917           NaN -0.01138   0.01384
# 3     2024-06-19 17:40:00.005       113.917           NaN -0.01233   0.01330
# 4     2024-06-19 17:40:30.005       143.917           NaN -0.01233   0.01277
# 5     2024-06-19 17:41:00.005       173.917           NaN -0.01233   0.01224
# 6     2024-06-19 17:41:30.005       203.917           NaN -0.01233   0.01224
# ...                       ...           ...           ...      ...       ...
# 1606  2024-06-22 19:20:00.005     48183.218           NaN  1.54300  14.99716
# 1607  2024-06-22 19:20:30.005     48213.218  END_OF_XOVER  1.54394  14.99609
# 1608  2024-06-22 19:21:00.005     48243.218           NaN  1.53067  11.96750
# 1609  2024-06-22 19:21:30.005     48273.218           NaN  1.51549   8.99550
# 1610  2024-06-22 19:22:00.005     48303.218           NaN  1.47471   2.98851
#
#       current_density  temp_anode_inlet_set  temp_anode_inlet  \
# 2            0.000266                  70.0         49.593044
# 3            0.000277                  70.0         54.440155
# 4            0.000255                  70.0         58.592991
# 5            0.000245                  70.0         61.780430
# 6            0.000266                  70.0         63.996456
# ...               ...                   ...               ...
# 1606         0.299943                  80.0         80.021370
# 1607         0.299922                  80.0         80.032341
# 1608         0.239350                  80.0         80.015884
# 1609         0.179910                  80.0         80.015884
# 1610         0.059770                  80.0         80.032341
#
#       temp_anode_outlet  temp_cathode_inlet_set  ...  cell_voltage_001  \
# 2             43.219200                     0.0  ...               NaN
# 3             47.928341                     0.0  ...               NaN
# 4             51.698734                     0.0  ...               NaN
# 5             54.901581                     0.0  ...               NaN
# 6             57.244316                     0.0  ...               NaN
# ...                 ...                     ...  ...               ...
# 1606          77.701607                     0.0  ...               NaN
# 1607          77.773697                     0.0  ...               NaN
# 1608          77.738014                     0.0  ...               NaN
# 1609          77.689445                     0.0  ...               NaN
# 1610          77.725929                     0.0  ...               NaN
#
#       cell_voltage_002  Gamry-01.current  Gamry-01.voltage  \
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4                  NaN               NaN               NaN
# 5                  NaN               NaN               NaN
# 6                  NaN               NaN               NaN
# ...                ...               ...               ...
# 1606               NaN               NaN               NaN
# 1607               NaN               NaN               NaN
# 1608               NaN               NaN               NaN
# 1609               NaN               NaN               NaN
# 1610               NaN               NaN               NaN
#
#       Gamry-01.current_density  pressure_anode_inlet  pressure_cathode_inlet  \
# 2                          NaN                   NaN                     NaN
# 3                          NaN                   NaN                     NaN
# 4                          NaN                   NaN                     NaN
# 5                          NaN                   NaN                     NaN
# 6                          NaN                   NaN                     NaN
# ...                        ...                   ...                     ...
# 1606                       NaN                   NaN                     NaN
# 1607                       NaN                   NaN                     NaN
# 1608                       NaN                   NaN                     NaN
# 1609                       NaN                   NaN                     NaN
# 1610                       NaN                   NaN                     NaN
#
#       pressure_cathode_outlet  signal_in_h2_in_o2_sensor  \
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# 5                         NaN                        NaN
# 6                         NaN                        NaN
# ...                       ...                        ...
# 1606                      NaN                        NaN
# 1607                      NaN                        NaN
# 1608                      NaN                        NaN
# 1609                      NaN                        NaN
# 1610                      NaN                        NaN
#
#       signal_in_o2_in_h2_sensor
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# ...                         ...
# 1606                        NaN
# 1607                        NaN
# 1608                        NaN
# 1609                        NaN
# 1610                        NaN
#
# [43775 rows x 38 columns]

# %%
xover_data_copy = xover_data.copy()

# %%
xover_data_copy = xover_data_copy[['Time Stamp', 'current', 'voltage', 'signal_in_h2_in_o2_sensor']]

xover_data_copy = xover_data_copy.dropna()

xover_data_copy = xover_data_copy.sort_values(by='Time Stamp')


xover_data_copy['Time Stamp'] = pd.to_datetime(xover_data_copy['Time Stamp'], format='%Y/%m/%d %H:%M:%S.%f')

xover_data_copy['time_diff'] = xover_data_copy['Time Stamp'].diff().dt.total_seconds().fillna(0) * 1000
xover_data_copy['time_running_total'] = xover_data_copy['time_diff'].cumsum()

xover_data_copy
# Out:
#                   Time Stamp  current  voltage  signal_in_h2_in_o2_sensor  \
# 2    2024-06-20 05:56:26.005  0.01117  0.15079                  -0.400000
# 3    2024-06-20 05:56:27.005  0.01224  0.14889                  -0.400000
# 4    2024-06-20 05:56:28.005  0.01117  0.14700                  -0.400000
# 5    2024-06-20 05:56:29.005  0.01224  0.14510                  -0.400000
# 6    2024-06-20 05:56:30.005  0.01224  0.14320                  -0.400000
# ...                      ...      ...      ...                        ...
# 1343 2024-06-22 05:24:18.005  0.00797  0.00095                   1.503574
# 1344 2024-06-22 05:24:20.005  0.00743  0.00000                   1.503574
# 1345 2024-06-22 05:24:22.005  0.00850  0.00000                   1.503574
# 1346 2024-06-22 05:24:24.005  0.00743  0.00000                   1.503574
# 1347 2024-06-22 05:24:26.005  0.00957  0.00000                   1.498886
#
#       time_diff  time_running_total
# 2           0.0                 0.0
# 3        1000.0              1000.0
# 4        1000.0              2000.0
# 5        1000.0              3000.0
# 6        1000.0              4000.0
# ...         ...                 ...
# 1343     2000.0         170872000.0
# 1344     2000.0         170874000.0
# 1345     2000.0         170876000.0
# 1346     2000.0         170878000.0
# 1347     2000.0         170880000.0
#
# [21094 rows x 6 columns]

# %%
xover_data_copy = xover_data.copy()




# rename the dateTime column
xover_data_copy = xover_data_copy.rename(columns = {'Unnamed: 0':'dateTime'}) 
xover_data_copy['dateTime'] = pd.to_datetime(xover_data_copy['dateTime'], format='%Y/%m/%d %H:%M:%S.%f')
xover_data_copy=xover_data_copy.sort_values(by='dateTime')



# add the cycle number to the dataframe
pattern = r'CYCLE\s\d{1,2}\b'
xover_data_copy['cycle'] = xover_data_copy['path'].apply(lambda x: extract_cycle_substring(x, pattern))

# add the test to the dataframe
pattern = r'CYCLE\s\d{1,2}\s(.*?)\s-\s'
xover_data_copy['test'] = xover_data_copy['path'].apply(lambda x: extract_cycle_substring(x, pattern))
xover_data_copy['test'] = xover_data_copy['test'].astype(str).str[8:-3]
xover_data_copy['test'] = xover_data_copy['test'].str.lstrip()


# get date from the datetime
xover_data_copy['date'] = xover_data_copy['dateTime'].astype(str).str[:10]




xover_data_copy['current_density']=xover_data_copy['current_density'].astype(float)
xover_data_copy['path'] = xover_data_copy['path'].astype(str)



to_drop = ['path']
xover_data_copy.drop(to_drop,axis=1 ,inplace=True)

# xover_data_copy= xover_data_copy.drop(xover_data_copy.index[:2])
xover_data_copy['test'].unique()
# Out:
# array(['Datafile Analyser', 'Dry Conditioning', 'Current Polar Up',
#        'Current Polar Down', 'EIS 1.2 A cm-2', 'EIS 0.6 A cm-2',
#        'EIS 0.1 A cm-2', 'CV', '3A 24-Hour Current Hold', 'H2 XOver',
#        'Post ESTOP Dry Conditioning'], dtype=object)

# %%
test_name = xover_data_copy['test'].unique().tolist()
test_name
# Out:
# ['Datafile Analyser',
#  'Dry Conditioning',
#  'Current Polar Up',
#  'Current Polar Down',
#  'EIS 1.2 A cm-2',
#  'EIS 0.6 A cm-2',
#  'EIS 0.1 A cm-2',
#  'CV',
#  '3A 24-Hour Current Hold',
#  'H2 XOver',
#  'Post ESTOP Dry Conditioning']

# %%
data_frame_of_tests = []

for test in test_name:
    sub_df = xover_data_copy.loc[xover_data_copy['test'] == test]
    columns_to_drop = sub_df.columns[sub_df.isnull().all()]
    sub_df.drop(columns=columns_to_drop, inplace=True)
    

    
    data_frame_of_tests.append(sub_df)
# Out:
# C:\Users\whiter04\Anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# combine tests

Datafile_Analyser = data_frame_of_tests[0]
Dry_Conditioning = data_frame_of_tests[1]
Current_Polar_Up = data_frame_of_tests[2]
Current_Polar_Down = data_frame_of_tests[3]

h_2_cross_over = data_frame_of_tests[-2]
current_hold = data_frame_of_tests[-3]

dfs = [Datafile_Analyser, 
       Dry_Conditioning, 
       Current_Polar_Up, 
       Current_Polar_Down, 
       h_2_cross_over,
       current_hold, 
       Datafile_Analyser]


master_data_frame = pd.concat(dfs).sort_values(by='dateTime')



# Calculate the difference between each datetime value and the running total of the time difference
master_data_frame['time_diff'] = master_data_frame['dateTime'].diff().dt.total_seconds().fillna(0) * 1000
master_data_frame['time_running_total'] = master_data_frame['time_diff'].cumsum()





to_drop = ['Unnamed: 1',
           'Unnamed: 2',
           'time_diff',
          'cycle',
          'test',
          'date',
          'dateTime']

master_data_frame = master_data_frame.drop(to_drop, axis=1).astype(float)


master_data_frame
# Out:
#       cell_voltage_001   current  current_density  temp_anode_inlet_set  \
# 2            -0.095167  -0.01262        -0.000505                  70.0
# 2            -0.095167  -0.01262        -0.000505                  70.0
# 2            -0.095167  -0.01262        -0.000505                  70.0
# 3            -0.095167  -0.01192        -0.000477                  70.0
# 3            -0.095167  -0.01192        -0.000477                  70.0
# ...                ...       ...              ...                   ...
# 1739          1.879790  75.00482         3.000193                  80.0
# 1739          1.879790  75.00482         3.000193                  80.0
# 1740          1.880171  75.00482         2.999912                  80.0
# 871           1.880171  75.00482         2.999912                  80.0
# 1740          1.880171  75.00482         2.999912                  80.0
#
#       temp_anode_inlet  temp_anode_outlet  temp_cathode_inlet_set  \
# 2            22.524658          22.211363                     0.0
# 2            22.524658          22.211363                     0.0
# 2            22.524658          22.211363                     0.0
# 3            23.574999          22.622944                     0.0
# 3            23.574999          22.622944                     0.0
# ...                ...                ...                     ...
# 1739         79.819145          78.329117                     0.0
# 1739         79.819145          78.329117                     0.0
# 1740         79.819145          78.354111                     0.0
# 871          79.819145          78.354111                     0.0
# 1740         79.819145          78.354111                     0.0
#
#       temp_cathode_inlet  temp_cathode_outlet  pressure_anode_set  ...  \
# 2              22.943993            22.664978                 0.0  ...
# 2              22.943993            22.664978                 0.0  ...
# 2              22.943993            22.664978                 0.0  ...
# 3              22.930300            22.651320                 0.0  ...
# 3              22.930300            22.651320                 0.0  ...
# ...                  ...                  ...                 ...  ...
# 1739           29.627552            34.574463                 2.0  ...
# 1739           29.627552            34.574463                 2.0  ...
# 1740           29.627552            34.560806                 2.0  ...
# 871            29.627552            34.560806                 2.0  ...
# 1740           29.627552            34.560806                 2.0  ...
#
#       pressure_cathode_outlet  flow_anode_di_water_supply_set  \
# 2                   -0.009439                             0.3
# 2                   -0.009439                             0.3
# 2                   -0.009439                             0.3
# 3                   -0.001021                             0.3
# 3                   -0.001021                             0.3
# ...                       ...                             ...
# 1739                 6.019177                             0.3
# 1739                 6.019177                             0.3
# 1740                 5.960248                             0.3
# 871                  5.960248                             0.3
# 1740                 5.960248                             0.3
#
#       flow_anode_di_water_supply  flow_cathode_di_water_supply_set  \
# 2                       0.149858                               0.0
# 2                       0.149858                               0.0
# 2                       0.149858                               0.0
# 3                       0.270174                               0.0
# 3                       0.270174                               0.0
# ...                          ...                               ...
# 1739                    0.300858                               0.0
# 1739                    0.300858                               0.0
# 1740                    0.300858                               0.0
# 871                     0.300858                               0.0
# 1740                    0.300858                               0.0
#
#       flow_cathode_di_water_supply  signal_in_resistivity_anode  \
# 2                              0.0                     0.142337
# 2                              0.0                     0.142337
# 2                              0.0                     0.142337
# 3                              0.0                     0.132591
# 3                              0.0                     0.132591
# ...                            ...                          ...
# 1739                           0.0                     0.230055
# 1739                           0.0                     0.230055
# 1740                           0.0                     0.215435
# 871                            0.0                     0.215435
# 1740                           0.0                     0.215435
#
#       signal_in_resistivity_cathode  signal_in_h2_in_o2_sensor  \
# 2                          0.580925                   0.278146
# 2                          0.580925                   0.278146
# 2                          0.580925                   0.278146
# 3                          0.585798                   0.276583
# 3                          0.585798                   0.276583
# ...                             ...                        ...
# 1739                       0.152083                   0.104703
# 1739                       0.152083                   0.104703
# 1740                       0.156957                   0.103140
# 871                        0.156957                   0.103140
# 1740                       0.156957                   0.103140
#
#       signal_in_o2_in_h2_sensor  time_running_total
# 2                          10.0        0.000000e+00
# 2                          10.0        0.000000e+00
# 2                          10.0        0.000000e+00
# 3                          10.0        3.000000e+04
# 3                          10.0        3.000000e+04
# ...                         ...                 ...
# 1739                       10.0        4.934550e+09
# 1739                       10.0        4.934550e+09
# 1740                       10.0        4.934580e+09
# 871                        10.0        4.934580e+09
# 1740                       10.0        4.934580e+09
#
# [461242 rows x 24 columns]

# %%
master_data_frame.to_csv('master_data_frame.csv')
