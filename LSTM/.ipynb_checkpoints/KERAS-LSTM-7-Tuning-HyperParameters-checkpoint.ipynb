# %%
# generate future y values using past x values AND greater offset y values

# %%
import pandas as pd
import numpy as np
import os
import shutil
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as plt
import re

from sklearn.model_selection import train_test_split

from sklearn.model_selection import GridSearchCV



from sklearn.preprocessing import MinMaxScaler


from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline

from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA

from sklearn.metrics import mean_squared_error, mean_absolute_error



from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Dropout
from scikeras.wrappers import KerasRegressor


import pickle

# %%
def convert_to_dataframe(x):
    return pd.DataFrame(x)

# %%
def create_sequences(features, target, seq_length, y_offset):
    X, y = [], []
    for i in range(seq_length, len(features)):
        # Current features sequence
        current_features = features[i-seq_length:i]
        
        # Offset previous y values sequence
        if i - seq_length - y_offset >= 0:
            offset_prev_y = target[i-seq_length-y_offset:i-y_offset]
        else:
            # If the offset is larger than the available data, fill with zeros or appropriate value
            offset_prev_y = np.zeros((seq_length, 1))
        
        # Combine current features with offset previous y values
        combined = np.hstack((current_features, offset_prev_y))
        
        X.append(combined)
        y.append(target[i])
    
    return np.array(X), np.array(y)

# %%
def predict_future(model, data, seq_length, future_steps):
    future_predictions = []
    current_sequence = data[-seq_length:].reshape(1, seq_length, data.shape[1])
    
    return(current_sequence)

# %%
df = pd.read_csv(r'C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\ELY-TimeSeries\Data\master_data_frame.csv')
df_copy = df.copy()
df_copy = df_copy.drop('Unnamed: 0',axis=1) 
df_copy


to_drop = ['temp_anode_inlet_set', 
           'temp_cathode_inlet_set', 
           'pressure_anode_set',
           'pressure_cathode_set', 
           'flow_anode_di_water_supply_set', 
           'flow_cathode_di_water_supply_set', 
          'flow_cathode_di_water_supply', 
           'signal_in_o2_in_h2_sensor']

df_copy = df_copy.drop(to_drop, axis=1)
df_copy


df_copy['seconds'] = (df_copy['time_running_total']/1000).astype(int)
df_copy['minutes'] = (df_copy['seconds']/60).astype(int)

# df_copy['hours'] = (df_copy['minutes']/60).astype(int)
# df_copy['days'] = (df_copy['hours']/24).astype(int)
# df_copy['weeks'] = (df_copy['days']/7).astype(int)
df_copy = df_copy.drop('time_running_total',axis=1)

# df_copy = df_copy.tail(150000)
df_copy
# Out:
#         cell_voltage_001   current  current_density  temp_anode_inlet  \
# 0              -0.095167  -0.01262        -0.000505         22.524658
# 1              -0.095167  -0.01262        -0.000505         22.524658
# 2              -0.095167  -0.01262        -0.000505         22.524658
# 3              -0.095167  -0.01192        -0.000477         23.574999
# 4              -0.095167  -0.01192        -0.000477         23.574999
# ...                  ...       ...              ...               ...
# 461237          1.879790  75.00482         3.000193         79.819145
# 461238          1.879790  75.00482         3.000193         79.819145
# 461239          1.880171  75.00482         2.999912         79.819145
# 461240          1.880171  75.00482         2.999912         79.819145
# 461241          1.880171  75.00482         2.999912         79.819145
#
#         temp_anode_outlet  temp_cathode_inlet  temp_cathode_outlet  \
# 0               22.211363           22.943993            22.664978
# 1               22.211363           22.943993            22.664978
# 2               22.211363           22.943993            22.664978
# 3               22.622944           22.930300            22.651320
# 4               22.622944           22.930300            22.651320
# ...                   ...                 ...                  ...
# 461237          78.329117           29.627552            34.574463
# 461238          78.329117           29.627552            34.574463
# 461239          78.354111           29.627552            34.560806
# 461240          78.354111           29.627552            34.560806
# 461241          78.354111           29.627552            34.560806
#
#         pressure_anode_inlet  pressure_anode_outlet  pressure_cathode_inlet  \
# 0                   0.015911              -0.026205               -0.009285
# 1                   0.015911              -0.026205               -0.009285
# 2                   0.015911              -0.026205               -0.009285
# 3                   0.184089              -0.026205               -0.009285
# 4                   0.184089              -0.026205               -0.009285
# ...                      ...                    ...                     ...
# 461237              1.992006               1.723834                6.002450
# 461238              1.992006               1.723834                6.002450
# 461239              1.992006               1.723834                6.002450
# 461240              1.992006               1.723834                6.002450
# 461241              1.992006               1.723834                6.002450
#
#         pressure_cathode_outlet  flow_anode_di_water_supply  \
# 0                     -0.009439                    0.149858
# 1                     -0.009439                    0.149858
# 2                     -0.009439                    0.149858
# 3                     -0.001021                    0.270174
# 4                     -0.001021                    0.270174
# ...                         ...                         ...
# 461237                 6.019177                    0.300858
# 461238                 6.019177                    0.300858
# 461239                 5.960248                    0.300858
# 461240                 5.960248                    0.300858
# 461241                 5.960248                    0.300858
#
#         signal_in_resistivity_anode  signal_in_resistivity_cathode  \
# 0                          0.142337                       0.580925
# 1                          0.142337                       0.580925
# 2                          0.142337                       0.580925
# 3                          0.132591                       0.585798
# 4                          0.132591                       0.585798
# ...                             ...                            ...
# 461237                     0.230055                       0.152083
# 461238                     0.230055                       0.152083
# 461239                     0.215435                       0.156957
# 461240                     0.215435                       0.156957
# 461241                     0.215435                       0.156957
#
#         signal_in_h2_in_o2_sensor  seconds  minutes
# 0                        0.278146        0        0
# 1                        0.278146        0        0
# 2                        0.278146        0        0
# 3                        0.276583       30        0
# 4                        0.276583       30        0
# ...                           ...      ...      ...
# 461237                   0.104703  4934550    82242
# 461238                   0.104703  4934550    82242
# 461239                   0.103140  4934580    82243
# 461240                   0.103140  4934580    82243
# 461241                   0.103140  4934580    82243
#
# [461242 rows x 17 columns]

# %%
import matplotlib.pyplot as plt

time_period = 'minutes'

df_time = df_copy.groupby(time_period).mean().reset_index()

downsampled_df = df_time.tail(24000).reset_index()

downsampled_df = downsampled_df[['minutes','cell_voltage_001','current','signal_in_h2_in_o2_sensor']]

downsampled_df[time_period] = pd.to_datetime('2024-05-16 00:00:00') + pd.to_timedelta(downsampled_df[time_period], unit='m')



plt.plot(downsampled_df['signal_in_h2_in_o2_sensor'])

plt.show()

downsampled_df = downsampled_df.set_index('minutes')
downsampled_df
# Out:
#                      cell_voltage_001    current  signal_in_h2_in_o2_sensor
# minutes
# 2024-06-24 08:37:00          1.863963  74.997810                   0.145329
# 2024-06-24 08:38:00          1.864345  75.001315                   0.145329
# 2024-06-24 08:39:00          1.864345  74.997810                   0.145329
# 2024-06-24 08:40:00          1.864154  74.997810                   0.145329
# 2024-06-24 08:41:00          1.864345  75.001315                   0.145329
# ...                               ...        ...                        ...
# 2024-07-12 02:39:00          1.879218  74.993604                   0.101265
# 2024-07-12 02:40:00          1.879294  75.000614                   0.103140
# 2024-07-12 02:41:00          1.879599  74.996408                   0.103140
# 2024-07-12 02:42:00          1.879790  75.000614                   0.103765
# 2024-07-12 02:43:00          1.880171  75.004820                   0.103140
#
# [24000 rows x 3 columns]

# %%
pipeline = Pipeline([
    ('scaler', MinMaxScaler()),

])

# Fit and transform the data


features = downsampled_df.drop(columns= ['signal_in_h2_in_o2_sensor'])
target = downsampled_df['signal_in_h2_in_o2_sensor']


features_trans = pipeline.fit_transform(features)
target_trans = pipeline.fit_transform(pd.DataFrame(target))



seq_length = 3  # Using  to predict the next minute
y_offset = 3500
X, y = create_sequences(features_trans, target_trans, seq_length, y_offset)

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
X.shape
# Out:
# (23997, 3, 3)

# %%
import keras.backend as K
from keras.callbacks import EarlyStopping
import keras_tuner as kt
from tensorflow.keras.layers import Dropout
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters

# %%
# Define the directory to store tuner data
tuner_dir = 'my_dir/untitled_project'

# Clear the Keras session
K.clear_session()

# Delete the tuner directory if it exists
if os.path.exists(tuner_dir):
    shutil.rmtree(tuner_dir)

# %%
def create_model(hp):
    model = Sequential()
    
    model.add(LSTM(hp.Int('input_unit', min_value = 90, max_value = 150, step = 10),
                   return_sequences = True,
                   input_shape = (X_train.shape[1], X_train.shape[2])))


    model.add(Dropout(hp.Float('Dropout_rate_1', min_value=0, max_value=0.5, step=0.1)))


    for i in range(hp.Int('n_layers', 1, 4)):
        model.add(LSTM(hp.Int(f'lstm_{i}_units', min_value=90, max_value=150, step=10),
                      return_sequences=True if i < hp.Int('n_layers', 1, 10) - 1 else False))


    model.add(Dropout(hp.Float('Dropout_rate_2', min_value=0, max_value=0.5, step=0.1)))


    model.add(Dense(1))         
                           
    
    
    model.compile(optimizer='adam', loss = 'mean_squared_error', metrics = ['mse'])
    return model

# %%
tuner= kt.RandomSearch(
        create_model,
        objective='mse',
        max_trials=30,
        executions_per_trial=3,
        directory='.\hp_test_5',
        project_name='hp_5'
        )

# %%
tuner.search(
    x=X_train,
    y=y_train,
    epochs=20,
    batch_size=64,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Trial 29 Complete [00h 07m 51s]
# mse: 0.01909838244318962
#
# Best mse So Far: 0.015365103570123514
# Total elapsed time: 09h 41m 20s
#
# Search: Running Trial #30
#
# Value             |Best Value So Far |Hyperparameter
# 150               |90                |input_unit
# 0                 |0.1               |Dropout_rate_1
# 4                 |4                 |n_layers
# 150               |110               |lstm_0_units
# 0.2               |0                 |Dropout_rate_2
# 90                |120               |lstm_1_units
# 110               |120               |lstm_2_units
# 140               |90                |lstm_3_units
#
# Epoch 1/20
# 300/300 [==============================] - 42s 85ms/step - loss: 0.0523 - mse: 0.0523 - val_loss: 0.0201 - val_mse: 0.0201
# Epoch 2/20
# 300/300 [==============================] - 29s 96ms/step - loss: 0.0217 - mse: 0.0217 - val_loss: 0.0204 - val_mse: 0.0204
# Epoch 3/20
# 300/300 [==============================] - 28s 93ms/step - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 4/20
# 300/300 [==============================] - 28s 93ms/step - loss: 0.0210 - mse: 0.0210 - val_loss: 0.0309 - val_mse: 0.0309
# Epoch 5/20
# 300/300 [==============================] - 28s 95ms/step - loss: 0.0206 - mse: 0.0206 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 6/20
# 300/300 [==============================] - 29s 95ms/step - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0159 - val_mse: 0.0159
# Epoch 7/20
# 300/300 [==============================] - 28s 94ms/step - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0165 - val_mse: 0.0165
# Epoch 8/20
# 300/300 [==============================] - 31s 102ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 9/20
# 300/300 [==============================] - 28s 93ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 10/20
# 300/300 [==============================] - 30s 99ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 11/20
# 300/300 [==============================] - 29s 97ms/step - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 12/20
# 300/300 [==============================] - 29s 98ms/step - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 13/20
# 300/300 [==============================] - 29s 98ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 14/20
# 300/300 [==============================] - 29s 98ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 15/20
# 300/300 [==============================] - 27s 91ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 16/20
# 300/300 [==============================] - 29s 95ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 17/20
# 300/300 [==============================] - 33s 112ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 18/20
# 300/300 [==============================] - 30s 99ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 19/20
# 300/300 [==============================] - 27s 90ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 20/20
# 300/300 [==============================] - 34s 113ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 1/20
# 300/300 [==============================] - 43s 99ms/step - loss: 0.0499 - mse: 0.0499 - val_loss: 0.0205 - val_mse: 0.0205
# Epoch 2/20
# 300/300 [==============================] - 26s 85ms/step - loss: 0.0215 - mse: 0.0215 - val_loss: 0.0234 - val_mse: 0.0234
# Epoch 3/20
# 300/300 [==============================] - 24s 80ms/step - loss: 0.0211 - mse: 0.0211 - val_loss: 0.0163 - val_mse: 0.0163
# Epoch 4/20
# 300/300 [==============================] - 26s 86ms/step - loss: 0.0210 - mse: 0.0210 - val_loss: 0.0212 - val_mse: 0.0212
# Epoch 5/20
# 300/300 [==============================] - 24s 79ms/step - loss: 0.0205 - mse: 0.0205 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 6/20
# 300/300 [==============================] - 23s 76ms/step - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0198 - val_mse: 0.0198
# Epoch 7/20
# 300/300 [==============================] - 22s 75ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 8/20
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0168 - val_mse: 0.0168
# Epoch 9/20
# 300/300 [==============================] - 23s 75ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 10/20
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 11/20
# 300/300 [==============================] - 23s 76ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 12/20
# 300/300 [==============================] - 23s 78ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 13/20
# 300/300 [==============================] - 23s 78ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 14/20
# 300/300 [==============================] - 23s 75ms/step - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 15/20
# 300/300 [==============================] - 23s 76ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 16/20
# 300/300 [==============================] - 23s 76ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0153 - val_mse: 0.0153
# Epoch 17/20
# 300/300 [==============================] - 42s 140ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 18/20
# 300/300 [==============================] - 37s 123ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0158 - val_mse: 0.0158
# Epoch 19/20
# 300/300 [==============================] - 32s 106ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 20/20
# 300/300 [==============================] - 40s 132ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 1/20
# 300/300 [==============================] - 16692s 56s/step - loss: 0.0523 - mse: 0.0523 - val_loss: 0.0173 - val_mse: 0.0173
# Epoch 2/20
# 300/300 [==============================] - 42s 139ms/step - loss: 0.0224 - mse: 0.0224 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 3/20
# 300/300 [==============================] - 34s 115ms/step - loss: 0.0211 - mse: 0.0211 - val_loss: 0.0169 - val_mse: 0.0169
# Epoch 4/20
# 300/300 [==============================] - 32s 105ms/step - loss: 0.0208 - mse: 0.0208 - val_loss: 0.0238 - val_mse: 0.0238
# Epoch 5/20
# 300/300 [==============================] - 31s 105ms/step - loss: 0.0205 - mse: 0.0205 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 6/20
# 182/300 [=================>............] - ETA: 12s - loss: 0.0203 - mse: 0.0203

# %%
best_model = tuner.get_best_models(num_models=1)[0]

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

for param, value in best_hps.values.items():
    print(f"{param}: {value}")
# Out:
# input_unit: 100
# Dropout_rate_1: 0.4
# n_layers: 3
# lstm_0_units: 70
# Dropout_rate_2: 0.0
# lstm_1_units: 90
# lstm_2_units: 80

# %%
best_model.save('model_mse_0.01639.keras')

# %%
predictions = best_model.predict(X_test)
# Out:
# 150/150 [==============================] - 4s 11ms/step

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual Crossover Rate')
plt.plot(predictions, label='Predicted Crossover Rate')
plt.legend()
plt.show()

# %%
predictions_train = best_model.predict(X_train)
# Out:
# 600/600 [==============================] - 5s 7ms/step

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_train, label='Actual Crossover Rate')
plt.plot(predictions_train, label='Predicted Crossover Rate')
plt.legend()
plt.show()

# %%
pd.DataFrame(predictions_train)
# Out:
#               0
# 0      0.371854
# 1      0.371868
# 2      0.371874
# 3      0.371864
# 4      0.371868
# ...         ...
# 19194  0.563098
# 19195  0.563091
# 19196  0.563087
# 19197  0.565372
# 19198  0.564013
#
# [19199 rows x 1 columns]

# %%
def generate_future(X, y_preds):
    X_futures = []
    n=0
    
    for i in X:
        d = [list(i[0])]
        d[0][2] = y_preds[n][0]
        
        X_futures.append([d[0]])
        n+=1
    X_futures = np.array(X_futures)
    
    return X_futures

# %%
x_f = generate_future(X_train,predictions_train)

# %%
predictions_f = best_model.predict(x_f)
# Out:
# 600/600 [==============================] - 3s 3ms/step

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_train, label='Actual Crossover Rate')
plt.plot(predictions_f, label='Predicted Crossover Rate')
plt.legend()
plt.show()

# %%
predictions_f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-c2e21c0a311c> in <module>
# ----> 1 predictions_f
#
# NameError: name 'predictions_f' is not defined
