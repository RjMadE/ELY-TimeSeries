# %%
# generate future y values using past x values AND greater offset y values

# %%
import pandas as pd
import numpy as np
import os
import shutil
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as plt
import re

from sklearn.model_selection import train_test_split

from sklearn.model_selection import GridSearchCV



from sklearn.preprocessing import MinMaxScaler


from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline

from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA

from sklearn.metrics import mean_squared_error, mean_absolute_error



from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Dropout
from scikeras.wrappers import KerasRegressor


import pickle

# %%
def convert_to_dataframe(x):
    return pd.DataFrame(x)

# %%
def create_sequences(features, target, seq_length, y_offset):
    X, y = [], []
    for i in range(seq_length, len(features)):
        # Current features sequence
        current_features = features[i-seq_length:i]
        
        # Offset previous y values sequence
        if i - seq_length - y_offset >= 0:
            offset_prev_y = target[i-seq_length-y_offset:i-y_offset]
        else:
            # If the offset is larger than the available data, fill with zeros or appropriate value
            offset_prev_y = np.zeros((seq_length, 1))
        
        # Combine current features with offset previous y values
        combined = np.hstack((current_features, offset_prev_y))
        
        X.append(combined)
        y.append(target[i])
    
    return np.array(X), np.array(y)

# %%
def predict_future(model, data, seq_length, future_steps):
    future_predictions = []
    current_sequence = data[-seq_length:].reshape(1, seq_length, data.shape[1])
    
    return(current_sequence)

# %%
df = pd.read_csv(r'C:\Users\whiter04\OneDrive - Johnson Matthey\00. cspark\ELY\ELY-TimeSeries\Data\master_data_frame.csv')
df_copy = df.copy()
df_copy = df_copy.drop('Unnamed: 0',axis=1) 
df_copy


to_drop = ['temp_anode_inlet_set', 
           'temp_cathode_inlet_set', 
           'pressure_anode_set',
           'pressure_cathode_set', 
           'flow_anode_di_water_supply_set', 
           'flow_cathode_di_water_supply_set', 
          'flow_cathode_di_water_supply', 
           'signal_in_o2_in_h2_sensor']

df_copy = df_copy.drop(to_drop, axis=1)
df_copy


df_copy['seconds'] = (df_copy['time_running_total']/1000).astype(int)
df_copy['minutes'] = (df_copy['seconds']/60).astype(int)

# df_copy['hours'] = (df_copy['minutes']/60).astype(int)
# df_copy['days'] = (df_copy['hours']/24).astype(int)
# df_copy['weeks'] = (df_copy['days']/7).astype(int)
df_copy = df_copy.drop('time_running_total',axis=1)

# df_copy = df_copy.tail(150000)
df_copy
# Out:
#         cell_voltage_001   current  current_density  temp_anode_inlet  \
# 0              -0.095167  -0.01262        -0.000505         22.524658
# 1              -0.095167  -0.01262        -0.000505         22.524658
# 2              -0.095167  -0.01262        -0.000505         22.524658
# 3              -0.095167  -0.01192        -0.000477         23.574999
# 4              -0.095167  -0.01192        -0.000477         23.574999
# ...                  ...       ...              ...               ...
# 461237          1.879790  75.00482         3.000193         79.819145
# 461238          1.879790  75.00482         3.000193         79.819145
# 461239          1.880171  75.00482         2.999912         79.819145
# 461240          1.880171  75.00482         2.999912         79.819145
# 461241          1.880171  75.00482         2.999912         79.819145
#
#         temp_anode_outlet  temp_cathode_inlet  temp_cathode_outlet  \
# 0               22.211363           22.943993            22.664978
# 1               22.211363           22.943993            22.664978
# 2               22.211363           22.943993            22.664978
# 3               22.622944           22.930300            22.651320
# 4               22.622944           22.930300            22.651320
# ...                   ...                 ...                  ...
# 461237          78.329117           29.627552            34.574463
# 461238          78.329117           29.627552            34.574463
# 461239          78.354111           29.627552            34.560806
# 461240          78.354111           29.627552            34.560806
# 461241          78.354111           29.627552            34.560806
#
#         pressure_anode_inlet  pressure_anode_outlet  pressure_cathode_inlet  \
# 0                   0.015911              -0.026205               -0.009285
# 1                   0.015911              -0.026205               -0.009285
# 2                   0.015911              -0.026205               -0.009285
# 3                   0.184089              -0.026205               -0.009285
# 4                   0.184089              -0.026205               -0.009285
# ...                      ...                    ...                     ...
# 461237              1.992006               1.723834                6.002450
# 461238              1.992006               1.723834                6.002450
# 461239              1.992006               1.723834                6.002450
# 461240              1.992006               1.723834                6.002450
# 461241              1.992006               1.723834                6.002450
#
#         pressure_cathode_outlet  flow_anode_di_water_supply  \
# 0                     -0.009439                    0.149858
# 1                     -0.009439                    0.149858
# 2                     -0.009439                    0.149858
# 3                     -0.001021                    0.270174
# 4                     -0.001021                    0.270174
# ...                         ...                         ...
# 461237                 6.019177                    0.300858
# 461238                 6.019177                    0.300858
# 461239                 5.960248                    0.300858
# 461240                 5.960248                    0.300858
# 461241                 5.960248                    0.300858
#
#         signal_in_resistivity_anode  signal_in_resistivity_cathode  \
# 0                          0.142337                       0.580925
# 1                          0.142337                       0.580925
# 2                          0.142337                       0.580925
# 3                          0.132591                       0.585798
# 4                          0.132591                       0.585798
# ...                             ...                            ...
# 461237                     0.230055                       0.152083
# 461238                     0.230055                       0.152083
# 461239                     0.215435                       0.156957
# 461240                     0.215435                       0.156957
# 461241                     0.215435                       0.156957
#
#         signal_in_h2_in_o2_sensor  seconds  minutes
# 0                        0.278146        0        0
# 1                        0.278146        0        0
# 2                        0.278146        0        0
# 3                        0.276583       30        0
# 4                        0.276583       30        0
# ...                           ...      ...      ...
# 461237                   0.104703  4934550    82242
# 461238                   0.104703  4934550    82242
# 461239                   0.103140  4934580    82243
# 461240                   0.103140  4934580    82243
# 461241                   0.103140  4934580    82243
#
# [461242 rows x 17 columns]

# %%
import matplotlib.pyplot as plt

time_period = 'minutes'

df_time = df_copy.groupby(time_period).mean().reset_index()

downsampled_df = df_time.tail(24000).reset_index()

downsampled_df = downsampled_df[['minutes','cell_voltage_001','current','signal_in_h2_in_o2_sensor']]

downsampled_df[time_period] = pd.to_datetime('2024-05-16 00:00:00') + pd.to_timedelta(downsampled_df[time_period], unit='m')



plt.plot(downsampled_df['signal_in_h2_in_o2_sensor'])

plt.show()

downsampled_df = downsampled_df.set_index('minutes')
downsampled_df
# Out:
#                      cell_voltage_001    current  signal_in_h2_in_o2_sensor
# minutes
# 2024-06-24 08:37:00          1.863963  74.997810                   0.145329
# 2024-06-24 08:38:00          1.864345  75.001315                   0.145329
# 2024-06-24 08:39:00          1.864345  74.997810                   0.145329
# 2024-06-24 08:40:00          1.864154  74.997810                   0.145329
# 2024-06-24 08:41:00          1.864345  75.001315                   0.145329
# ...                               ...        ...                        ...
# 2024-07-12 02:39:00          1.879218  74.993604                   0.101265
# 2024-07-12 02:40:00          1.879294  75.000614                   0.103140
# 2024-07-12 02:41:00          1.879599  74.996408                   0.103140
# 2024-07-12 02:42:00          1.879790  75.000614                   0.103765
# 2024-07-12 02:43:00          1.880171  75.004820                   0.103140
#
# [24000 rows x 3 columns]

# %%
# feture engineering 

# adding trend to provide the model with increasing trend data

trend = (np.arange(len(downsampled_df))).tolist()
trend


downsampled_df['trend'] = trend
downsampled_df
# Out:
#                      cell_voltage_001    current  signal_in_h2_in_o2_sensor  \
# minutes
# 2024-06-24 08:37:00          1.863963  74.997810                   0.145329
# 2024-06-24 08:38:00          1.864345  75.001315                   0.145329
# 2024-06-24 08:39:00          1.864345  74.997810                   0.145329
# 2024-06-24 08:40:00          1.864154  74.997810                   0.145329
# 2024-06-24 08:41:00          1.864345  75.001315                   0.145329
# ...                               ...        ...                        ...
# 2024-07-12 02:39:00          1.879218  74.993604                   0.101265
# 2024-07-12 02:40:00          1.879294  75.000614                   0.103140
# 2024-07-12 02:41:00          1.879599  74.996408                   0.103140
# 2024-07-12 02:42:00          1.879790  75.000614                   0.103765
# 2024-07-12 02:43:00          1.880171  75.004820                   0.103140
#
#                      trend
# minutes
# 2024-06-24 08:37:00      0
# 2024-06-24 08:38:00      1
# 2024-06-24 08:39:00      2
# 2024-06-24 08:40:00      3
# 2024-06-24 08:41:00      4
# ...                    ...
# 2024-07-12 02:39:00  23995
# 2024-07-12 02:40:00  23996
# 2024-07-12 02:41:00  23997
# 2024-07-12 02:42:00  23998
# 2024-07-12 02:43:00  23999
#
# [24000 rows x 4 columns]

# %%
pipeline = Pipeline([
    ('scaler', MinMaxScaler()),

])

# Fit and transform the data


features = downsampled_df.drop(columns= ['signal_in_h2_in_o2_sensor'])
target = downsampled_df['signal_in_h2_in_o2_sensor']


features_trans = pipeline.fit_transform(features)
target_trans = pipeline.fit_transform(pd.DataFrame(target))



seq_length = 3  # Using  to predict the next minute
y_offset = 3500
X, y = create_sequences(features_trans, target_trans, seq_length, y_offset)

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
X.shape
# Out:
# (23997, 3, 4)

# %%
import keras.backend as K
from keras.callbacks import EarlyStopping
import keras_tuner as kt
from tensorflow.keras.layers import Dropout
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters

# %%
# Define the directory to store tuner data
tuner_dir = 'my_dir/untitled_project'

# Clear the Keras session
K.clear_session()

# Delete the tuner directory if it exists
if os.path.exists(tuner_dir):
    shutil.rmtree(tuner_dir)

# %%
def create_model(hp):
    model = Sequential()
    
    model.add(LSTM(hp.Int('input_unit', min_value = 90, max_value = 150, step = 10),
                   return_sequences = True,
                   input_shape = (X_train.shape[1], X_train.shape[2])))


    model.add(Dropout(hp.Float('Dropout_rate_1', min_value=0, max_value=0.5, step=0.1)))


    for i in range(hp.Int('n_layers', 1, 3)):
        model.add(LSTM(hp.Int(f'lstm_{i}_units', min_value=90, max_value=150, step=10),
                      return_sequences=True if i < hp.Int('n_layers', 1, 10) - 1 else False))


    model.add(Dropout(hp.Float('Dropout_rate_2', min_value=0, max_value=0.5, step=0.1)))


    model.add(Dense(1))         
                           
    
    
    model.compile(optimizer='adam', loss = 'mean_squared_error', metrics = ['mse'])
    return model

# %%
tuner= kt.RandomSearch(
        create_model,
        objective='mse',
        max_trials=30,
        executions_per_trial=3,
        directory='.\hp_test_7',
        project_name='hp_8'
        )

# %%
tuner.search(
    x=X_train,
    y=y_train,
    epochs=20,
    batch_size=128,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Trial 8 Complete [00h 06m 42s]
# mse: 0.017236992716789246
#
# Best mse So Far: 0.00933102611452341
# Total elapsed time: 01h 08m 34s
#
# Search: Running Trial #9
#
# Value             |Best Value So Far |Hyperparameter
# 110               |120               |input_unit
# 0.3               |0.4               |Dropout_rate_1
# 3                 |3                 |n_layers
# 110               |90                |lstm_0_units
# 0.2               |0.1               |Dropout_rate_2
# 140               |90                |lstm_1_units
# 100               |90                |lstm_2_units
#
# Epoch 1/20
# 150/150 [==============================] - 30s 116ms/step - loss: 0.0672 - mse: 0.0672 - val_loss: 0.0340 - val_mse: 0.0340
# Epoch 2/20
# 150/150 [==============================] - 12s 82ms/step - loss: 0.0302 - mse: 0.0302 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 3/20
# 150/150 [==============================] - 14s 97ms/step - loss: 0.0205 - mse: 0.0205 - val_loss: 0.0158 - val_mse: 0.0158
# Epoch 4/20
# 150/150 [==============================] - 14s 90ms/step - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0171 - val_mse: 0.0171
# Epoch 5/20
# 150/150 [==============================] - 11s 73ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0173 - val_mse: 0.0173
# Epoch 6/20
# 150/150 [==============================] - 13s 83ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 7/20
# 150/150 [==============================] - 13s 83ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 8/20
# 150/150 [==============================] - 10s 69ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 9/20
# 150/150 [==============================] - 13s 84ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0171 - val_mse: 0.0171
# Epoch 10/20
# 150/150 [==============================] - 12s 83ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0171 - val_mse: 0.0171
# Epoch 11/20
# 150/150 [==============================] - 12s 80ms/step - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0166 - val_mse: 0.0166
# Epoch 12/20
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 13/20
# 150/150 [==============================] - 10s 66ms/step - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 14/20
# 150/150 [==============================] - 15s 98ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 15/20
# 150/150 [==============================] - 16s 103ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 16/20
# 150/150 [==============================] - 12s 81ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 17/20
# 150/150 [==============================] - 11s 73ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 18/20
# 150/150 [==============================] - 10s 69ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 19/20
# 150/150 [==============================] - 10s 69ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 20/20
# 150/150 [==============================] - 10s 65ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 1/20
# 150/150 [==============================] - ETA: 0s - loss: 0.0662 - mse: 0.0662
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-525f60789244> in <module>
# ----> 1 tuner.search(
#       2     x=X_train,
#       3     y=y_train,
#       4     epochs=20,
#       5     batch_size=128,
#
# ~\Anaconda3\lib\site-packages\keras_tuner\src\engine\base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     232
#     233             self.on_trial_begin(trial)
# --> 234             self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235             self.on_trial_end(trial)
#     236         self.on_search_end()
#
# ~\Anaconda3\lib\site-packages\keras_tuner\src\engine\base_tuner.py in _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272     def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273         try:
# --> 274             self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275             trial.status = trial_module.TrialStatus.COMPLETED
#     276             return
#
# ~\Anaconda3\lib\site-packages\keras_tuner\src\engine\base_tuner.py in _run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     237
#     238     def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239         results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240         if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241             self.oracle.objective.name
#
# ~\Anaconda3\lib\site-packages\keras_tuner\src\engine\tuner.py in run_trial(self, trial, *args, **kwargs)
#     312             callbacks.append(model_checkpoint)
#     313             copied_kwargs["callbacks"] = callbacks
# --> 314             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     315
#     316             histories.append(obj_value)
#
# ~\Anaconda3\lib\site-packages\keras_tuner\src\engine\tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     231         hp = trial.hyperparameters
#     232         model = self._try_build(hp)
# --> 233         results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     234
#     235         # Save the build config for model loading later.
#
# ~\Anaconda3\lib\site-packages\keras_tuner\src\engine\hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     147             If return a float, it should be the `objective` value.
#     148         """
# --> 149         return model.fit(*args, **kwargs)
#     150
#     151
#
# ~\Anaconda3\lib\site-packages\keras\src\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\Anaconda3\lib\site-packages\keras\src\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1789                             pss_evaluation_shards=self._pss_evaluation_shards,
#    1790                         )
# -> 1791                     val_logs = self.evaluate(
#    1792                         x=val_x,
#    1793                         y=val_y,
#
# ~\Anaconda3\lib\site-packages\keras\src\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\Anaconda3\lib\site-packages\keras\src\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2198                         ):
#    2199                             callbacks.on_test_batch_begin(step)
# -> 2200                             logs = test_function_runner.run_step(
#    2201                                 dataset_or_iterator,
#    2202                                 data_handler,
#
# ~\Anaconda3\lib\site-packages\keras\src\engine\training.py in run_step(self, dataset_or_iterator, data_handler, step, unused_shards)
#    3998
#    3999     def run_step(self, dataset_or_iterator, data_handler, step, unused_shards):
# -> 4000         tmp_logs = self._function(dataset_or_iterator)
#    4001         if data_handler.should_sync:
#    4002             context.async_wait()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     823
#     824       with OptionalXlaContext(self._jit_compile):
# --> 825         result = self._call(*args, **kwds)
#     826
#     827       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     895               args, kwds))
#     896       # If we did not create any variables the trace we have is good enough.
# --> 897       return self._concrete_variable_creation_fn._call_flat(   # pylint: disable=protected-access
#     898           filtered_flat_args,
#     899           self._concrete_variable_creation_fn.captured_inputs)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs)
#    1347         and executing_eagerly):
#    1348       # No tape is watching; skip to running the function.
# -> 1349       return self._build_call_outputs(self._inference_function(*args))
#    1350     forward_backward = self._select_forward_and_backward_functions(
#    1351         args,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py in __call__(self, *args)
#     194         with record.stop_recording():
#     195           if self._bound_context.executing_eagerly():
# --> 196             outputs = self._bound_context.call_function(
#     197                 self.name,
#     198                 list(args),
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1455     cancellation_context = cancellation.context()
#    1456     if cancellation_context is None:
# -> 1457       outputs = execute.execute(
#    1458           name.decode("utf-8"),
#    1459           num_outputs=num_outputs,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
best_model = tuner.get_best_models(num_models=1)[0]

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

for param, value in best_hps.values.items():
    print(f"{param}: {value}")
# Out:
# input_unit: 120
# Dropout_rate_1: 0.4
# n_layers: 3
# lstm_0_units: 90
# Dropout_rate_2: 0.1
# lstm_1_units: 90
# lstm_2_units: 90

# %%
best_model.save('model_mse_0.0093.keras')

# %%
predictions = best_model.predict(X_test)
# Out:
# 150/150 [==============================] - 4s 9ms/step

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual Crossover Rate')
plt.plot(predictions, label='Predicted Crossover Rate')
plt.legend()
plt.show()

# %%
predictions_train = best_model.predict(X_train)
# Out:
# 600/600 [==============================] - 6s 7ms/step

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_train, label='Actual Crossover Rate')
plt.plot(predictions_train, label='Predicted Crossover Rate')
plt.legend()
plt.show()

# %%
def generate_future(X, y_preds):
    X_futures = []
    n=0
    
    for i in X:
        d = [list(i[0])]
        d[0][2] = y_preds[n][0]
        
        X_futures.append([d[0]])
        n+=1
    X_futures = np.array(X_futures)
    
    return X_futures

# %%
x_f = generate_future(X_train,predictions_train)

# %%
predictions_f = best_model.predict(x_f)
# Out:
# 600/600 [==============================] - 4s 4ms/step

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_train, label='Actual Crossover Rate')
plt.plot(predictions_f, label='Predicted Crossover Rate')
plt.legend()
plt.show()

# %%
predictions_f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-c2e21c0a311c> in <module>
# ----> 1 predictions_f
#
# NameError: name 'predictions_f' is not defined
